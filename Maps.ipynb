# %%
import urllib.request
import json

# %% [markdown]
# Norte: 51.678488
#
# Sur: 51.313660
#
# Oeste: -0.492840
#
# Este: 0.333957
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=51.634656,-0.134360&radius=1500&type=hospital&key=AIzaSyC_8QhTAOkJO5MpOIDbqlEvk4wFjYd4myQ

# %%
vertmov = (51.678488  - 51.313660) /40.64

# %%
hormov = (0.492840 + 0.333957) / 57

# %%
y = 51.313660

# %%
x = -0.492840

# %%
api_key = 'key=AIzaSyC_8QhTAOkJO5MpOIDbqlEvk4wFjYd4myQ'

# %%
endpoint = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?'

# %%
location = "location="

# %%
place = "type=hospital"

# %%
rad = "radius=1500"

# %%
listaCoord = []

# %%
x = -0.492840
for i in range (57):
    x += hormov
    y = 51.313660
    for j in range(41):
        requestUrl = endpoint + location + str(y) + "," + str(x) + "&" + rad + "&"+ place + "&" + api_key
        response = urllib.request.urlopen(requestUrl)
        res = response.read()
        json_obj = json.loads(res)
        y += vertmov
        for item in json_obj["results"]:
            if(([item["geometry"]["location"]["lat"], item["geometry"]["location"]["lng"]]) not in listaCoord):
                listaCoord.append([item["geometry"]["location"]["lat"], item["geometry"]["location"]["lng"]])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-102-f89039b55d7c> in <module>()
#       5     for j in range(41):
#       6         requestUrl = endpoint + location + str(y) + "," + str(x) + "&" + rad + "&"+ place + "&" + api_key
# ----> 7         response = urllib.request.urlopen(requestUrl)
#       8         res = response.read()
#       9         json_obj = json.loads(res)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# ...

# %%
listaCoord
# Out:
# [[51.373309, -0.4607197],
#  [51.3742221, -0.4603231],
#  [51.3717821, -0.4589434000000001],
#  [51.4332942, -0.4622367999999999],
#  [51.4323004, -0.4620211999999999],
#  [51.4379962, -0.4705207],
#  [51.444057, -0.4729979999999999],
#  [51.45138069999999, -0.4761017],
#  [51.4440232, -0.4699928],
#  [51.5048045, -0.4761826],
#  [51.5123419, -0.4717459000000001],
#  [51.5252278, -0.461251],
#  [51.53182289999999, -0.4723148],
#  [51.52572809999999, -0.4617971],
#  [51.524294, -0.459065],
#  [51.5244519, -0.4613241],
#  [51.5240439, -0.4609135999999999],
#  [51.5259081, -0.4616525],
#  [51.528324, -0.4605139999999999],
#  [51.5260543, -0.4587143999999999],
#  [51.54632650000001, -0.4756938000000002],
#  [51.5421668, -0.4719067999999999],
#  [51.553263, -0.486156],
#  [51.60689199999999, -0.4827170000000001],
#  [51.60671999999999, -0.482768],
#  [51.6392921, -0.4717881999999999],
#  [51.63777040000001, -0.4686020000000001],
#  [51.68117700000001, -0.492078],
# ...

# %%
import pandas as pd

# %%
coordenadas = pd.DataFrame(listaCoord)

# %%
coordenadas.head()
# Out:
#            0         1
# 0  51.373309 -0.460720
# 1  51.374222 -0.460323
# 2  51.371782 -0.458943
# 3  51.433294 -0.462237
# 4  51.432300 -0.462021

# %%
coordenadas.to_csv("coordenadas.csv")

# %%
df = pd.read_csv("coordenadas.csv")
